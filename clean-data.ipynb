# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
table = pd.read_csv('./fifa-dataset/players_15.csv')
# Out:
# /var/folders/q5/y7w8wy7n4f51qfry4bp9yks00000gn/T/ipykernel_39958/1946397316.py:1: DtypeWarning: Columns (0: gk) have mixed types. Specify dtype option on import or set low_memory=False.
#   table = pd.read_csv('./fifa-dataset/players_15.csv')

# %%
table.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16155 entries, 0 to 16154
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(17), int64(43), object(1), str(49)
# memory usage: 13.6+ MB

# %%
#Count the null values for each column that contains NAs
null_counts = table.isnull().sum()
for column_name, count in null_counts.items():
    if count > 0:
        print(f"{column_name}, {count}")
# Out:
# value_eur, 311
# wage_eur, 239
# club_team_id, 239
# club_name, 239
# league_name, 239
# league_level, 239
# club_position, 239
# club_jersey_number, 239
# club_loaned_from, 15243
# club_joined, 1151
# club_contract_valid_until, 239
# nation_team_id, 15074
# nation_position, 15074
# nation_jersey_number, 15074
# release_clause_eur, 16155
# player_tags, 14919
# player_traits, 9556
# pace, 1775
# shooting, 1775
# passing, 1775
# dribbling, 1775
# defending, 1775
# physic, 1775
# mentality_composure, 16155
# goalkeeping_speed, 14380
# club_logo_url, 239
# club_flag_url, 239
# nation_logo_url, 15074

# %%
table[table['player_positions']=='GK'].info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1775 entries, 4 to 16148
# Columns: 110 entries, sofifa_id to nation_flag_url
# dtypes: float64(17), int64(43), object(1), str(49)
# memory usage: 1.5+ MB

# %%
#Drop all Goalkeepers from the table
table.drop(table[table['player_positions'] == 'GK'].index, inplace=True)

# %%
#Dropping columns that are largely null values/would not provide spatial data to the model
columns_to_drop = [
    'club_loaned_from', 'nation_team_id', 'nation_position',
    'nation_jersey_number', 'release_clause_eur', 'player_tags', 'player_traits',
    'mentality_composure', 'goalkeeping_speed',
    'nation_logo_url', 'club_logo_url', 'club_flag_url'
]

columns_to_drop_2 = [
'value_eur','wage_eur','club_team_id','club_name','league_name','league_level','club_position','club_jersey_number','club_joined', 'club_contract_valid_until'
]

columns_to_drop_3 = [
'goalkeeping_diving','goalkeeping_handling','goalkeeping_kicking','goalkeeping_positioning','goalkeeping_reflexes','player_face_url','nation_flag_url'   
]

table=table.drop(columns=columns_to_drop+columns_to_drop_2+columns_to_drop_3)

# %%
table.to_csv('players_2015.csv')

# %%
print('gk' in table.columns)
# Out:
# True

# %%
table = table.drop(columns='gk')

# %%
columns_to_convert = [
    'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram',
    'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb',
    'lb', 'lcb', 'cb', 'rcb', 'rb'
]

# 2. Apply the conversion to each column
for col in columns_to_convert:
    # Use eval to solve the string expression, then convert to int
    table[col] = table[col].apply(eval).astype(int)

# 3. Verify the conversion
print(table[columns_to_convert].info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 14380 entries, 0 to 16154
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ls      14380 non-null  int64
#  1   st      14380 non-null  int64
#  2   rs      14380 non-null  int64
#  3   lw      14380 non-null  int64
#  4   lf      14380 non-null  int64
#  5   cf      14380 non-null  int64
#  6   rf      14380 non-null  int64
#  7   rw      14380 non-null  int64
#  8   lam     14380 non-null  int64
#  9   cam     14380 non-null  int64
#  10  ram     14380 non-null  int64
#  11  lm      14380 non-null  int64
#  12  lcm     14380 non-null  int64
#  13  cm      14380 non-null  int64
#  14  rcm     14380 non-null  int64
#  15  rm      14380 non-null  int64
#  16  lwb     14380 non-null  int64
#  17  ldm     14380 non-null  int64
#  18  cdm     14380 non-null  int64
#  19  rdm     14380 non-null  int64
#  20  rwb     14380 non-null  int64
#  21  lb      14380 non-null  int64
# ...

# %%
table.to_csv('players_2015.csv', index=False)

# %%
clean_df1 = pd.read_csv('./clean_data/cleaned_csvs/players_2015.csv')
clean_df2 = pd.read_csv('./clean_data/cleaned_csvs/players_2016.csv')

# %%
clean_df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13924 entries, 0 to 13923
# Data columns (total 81 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   13924 non-null  int64
#  1   sofifa_id                    13924 non-null  int64
#  2   player_url                   13924 non-null  str
#  3   short_name                   13924 non-null  str
#  4   long_name                    13924 non-null  str
#  5   player_positions             13924 non-null  str
#  6   overall                      13924 non-null  int64
#  7   potential                    13924 non-null  int64
#  8   age                          13924 non-null  int64
#  9   dob                          13924 non-null  str
#  10  height_cm                    13924 non-null  int64
#  11  weight_kg                    13924 non-null  int64
#  12  nationality_id               13924 non-null  int64
# ...

# %%
cols_in_df1_not_df2 = clean_df1.columns.difference(clean_df2.columns)
cols_in_df1_not_df2
# Out:
# Index([], dtype='str')
